# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(5,10,'o')
plt.show()

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plotting Example')
# Out:
# Text(0.5, 1.0, 'Plotting Example')
